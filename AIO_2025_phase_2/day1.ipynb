# %%
print('hi')
# Out:
# hi

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2,3,4,5]
b = [2*x*x+x+1 for x in a]
plt.plot(a,b,marker = 'o')
plt.title('Matplotlib Test')
plt.xlabel('X')
plt.ylabel(('Y'))
plt.show()
