# %%
# !pip install pygwalker
# Out:
# ...
#   Using cached pygwalker-0.4.9.14-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached anywidget-0.9.18-py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached duckdb-1.2.1-cp312-cp312-win_amd64.whl.metadata (995 bytes)
# ...
#   Using cached gw_dsl_parser-0.1.49.1-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached ipylab-1.0.0-py3-none-any.whl.metadata (6.7 kB)
# ...
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached kanaries_track-0.0.5-py3-none-any.whl.metadata (913 bytes)
# ...
#   Using cached pyarrow-19.0.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached quickjs-1.19.4-cp312-cp312-win_amd64.whl.metadata (609 bytes)
# ...

# %%
import pygwalker as pyg
import pandas as pd

data = pd.read_csv('advertising.csv')
pyg.walk(data)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-0006317d35b3caabiRdALwG7qug0fctn" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "0006317d35b3caabiRdALwG7qug0fctn") {
#             var iframe = document.getElementById("gwalker-0006317d35b3caabiRdALwG7qug0fctn");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
